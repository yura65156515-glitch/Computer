# %% [markdown]
# <a href="https://colab.research.google.com/github/yura65156515-glitch/Computer/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello, world")

#integer
x  = 3
print ("정수: %01d, %02d, %03d, %04d, %05d"
      % (x,x,x,x,x))

#float
x = 256.123
print ("실수: %.0f, %.1f, %.2f"
      % (x,x,x))

#string
x="Hello,world"
print("문자열: [%s]"%(x))
# Out:
# Hello, world
# 정수: 3, 03, 003, 0003, 00003
# 실수: 256, 256.1, 256.12
# 문자열: [Hello,world]

# %%
contents = ["Regression","Classification","SYM","Clustering","Dimension reduction", "NN","CNN","AE","GAN","RNN"]
for con in contents:
  if con in ["Regression","Classification","SYM","Clustering","Dimension reduction"]:
    print ("%s 은(는) 기계학습 내용입니다."%con)
  elif con in ["CNN"]:
    print("%s은(는) convolutional neural network 입니다."%con)
  else:
    print("%s은(는) 심층학습 내용입니다."%con)
# Out:
# Regression 은(는) 기계학습 내용입니다.
# Classification 은(는) 기계학습 내용입니다.
# SYM 은(는) 기계학습 내용입니다.
# Clustering 은(는) 기계학습 내용입니다.
# Dimension reduction 은(는) 기계학습 내용입니다.
# NN은(는) 심층학습 내용입니다.
# CNN은(는) convolutional neural network 입니다.
# AE은(는) 심층학습 내용입니다.
# GAN은(는) 심층학습 내용입니다.
# RNN은(는) 심층학습 내용입니다.

# %%
for (i,con) in enumerate(contents):
  print ("[%d/%d]: %s"%(i,len(contents), con))
# Out:
# [0/10]: Regression
# [1/10]: Classification
# [2/10]: SYM
# [3/10]: Clustering
# [4/10]: Dimension reduction
# [5/10]: NN
# [6/10]: CNN
# [7/10]: AE
# [8/10]: GAN
# [9/10]: RNN

# %%
def sum(a,b):
  return a+b

x = 10.0
y = 20.0
print ("%.1f + %.1f = %.1f" % (x,y,sum(x,y)))
# Out:
# 10.0 + 20.0 = 30.0

# %%
a = []
b=[1,2,3]
c=["Hello",",","world"]
d=[1,2,3,"x","y","z"]
x=[]
print (x)

x.append('a')
print (x)

x.append(123)
print(x)

x.append(["a","b"])
print (x)
# Out:
# []
# ['a']
# ['a', 123]
# ['a', 123, ['a', 'b']]

# %%
dic = dict()
dic["name"] = "Heekyung"
dic["town"] = "Goyang city"
dic["job"] = "Assistant professor"
print (dic)
# Out:
# {'name': 'Heekyung', 'town': 'Goyang city', 'job': 'Assistant professor'}

# %%
class student:
  def __init__(self,name):
    self.name = name
  def study(self, hard = False) :
    if hard :
      print ("%s학생은 공부를 열심히합니다"%self.name)
    else:
       print ("%s학생은 공부합니다"%self.name)

s = student("Heekyung")
s.study()
s.study(hard = True)
# Out:
# Heekyung학생은 공부합니다
# Heekyung학생은 공부를 열심히합니다
